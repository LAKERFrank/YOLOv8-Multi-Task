# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# %cd /content/gdrive/MyDrive/TrackNetv2/

# %%
#python3 Frame_Generator.py <videoPath> <outputFrameFolder>
# !python3 Frame_Generator.py train_data/match1/video train_data/match1/frame
